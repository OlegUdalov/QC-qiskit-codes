# %% [markdown]
# # Data presentation

# %%
import numpy as np
import time
import sys
import math

# %%
#dP as a function of qubits number and circuit depth N (number of layer in the first half of the circuit)
#Block modification precision is about 0.04
#              2       4       8       16        32        64         128
data_set_1 = [...
              [0.0033, 0.0012, 0.0025, 0.0072,  0.0100,    0,         0],...     #2
              [0,     0,      0,       0.0085,  0.0378,    0.068,     0.096],... #4
              [0,     0,      0,       0.0394,  0.045 ,    0.089,     0.234],... #6
              [0,     0,      0,       0.0410,  0.105 ,    0.120,     0.300],... #8
              [0,     0,      0,       0.0610,  0.193 ,    0.284,     0.234],... #10
              [0,     0,      0,       0.195 ,  0.208 ,    0.251,     0.530],... #12
              [0,     0,      0,       0.073 ,  0.215 ,    0.340,     0.000],... #14
#Block modification precision is about 0.015              
data_set_2 = [...
              [0,     0.00  , 0.00   , 0.00  ,  0.0000,    0,         0],...     #2
              [0,     0.0001, 0,       0.0017,  0.012 ,    0.005,     0],...     #4
              [0,     0.0004, 0,       0.011 ,  0.0085,    0.024,     0.],...    #6
              [0,     0.0009, 0,       0.0032,  0.008 ,    0.042,     0.000],... #8
              [0,     0.0003, 0,       0.0045,  0.035 ,    0.058,     0.000],... #10
              [0,     0.027,  0,       0.037 ,  0.0085,    0.090,     0.000],... #12
              [0,     0.003,  0,       0.006 ,  0.0085,    0.032,     0.000],... #14
